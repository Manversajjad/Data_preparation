# %% [markdown]
# <a href="https://colab.research.google.com/github/Manversajjad/Data_preparation/blob/main/Data_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Deduplication Using Pandas

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame([('Allen Iverson', 'The Answer'), ('Earvin Johnson', 'Magic'), ('Michael Jordan', 'Air Jordan'),
                    ('Rodney Hundley', 'Hot Rod'), ('John Williams', 'Hot Rod'),
                    ('George Gervin', 'Iceman'), ('Michael Jordan', 'Air Jordan'),
                    ('John Salley', 'Spider'), ('Jerry Sloan', 'Spider'),
                    ('Charles Barkley', 'The Chuckster')],
                   columns=['Player', 'Nickname'])

df1
# Out:
#             Player       Nickname
# 0    Allen Iverson     The Answer
# 1   Earvin Johnson          Magic
# 2   Michael Jordan     Air Jordan
# 3   Rodney Hundley        Hot Rod
# 4    John Williams        Hot Rod
# 5    George Gervin         Iceman
# 6   Michael Jordan     Air Jordan
# 7      John Salley         Spider
# 8      Jerry Sloan         Spider
# 9  Charles Barkley  The Chuckster

# %% [markdown]
# ***Using .Duplicated() Method to Identify Duplicate Values In a Data-Frame***

# %%
df1.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# dtype: bool

# %% [markdown]
# ## **To check whether a certain Column has duplicates using subset Option in Duplicated Function**

# %%
df1.duplicated(subset='Nickname')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6     True
# 7    False
# 8     True
# 9    False
# dtype: bool

# %% [markdown]
# Removing Duplicate Values. But keep the last value

# %%
df1 = pd.DataFrame([('Allen Iverson', 'The Answer'), ('Earvin Johnson', 'Magic'), ('Michael Jordan', 'Air Jordan'),
                    ('Rodney Hundley', 'Hot Rod'), ('John Williams', 'Hot Rod'),
                    ('George Gervin', 'Iceman'), ('Michael Jordan', 'Air Jordan'),
                    ('John Salley', 'Spider'), ('Jerry Sloan', 'Spider'),
                    ('Charles Barkley', 'The Chuckster')],
                   columns=['Player', 'Nickname'])

df1
# Out:
#             Player       Nickname
# 0    Allen Iverson     The Answer
# 1   Earvin Johnson          Magic
# 2   Michael Jordan     Air Jordan
# 3   Rodney Hundley        Hot Rod
# 4    John Williams        Hot Rod
# 5    George Gervin         Iceman
# 6   Michael Jordan     Air Jordan
# 7      John Salley         Spider
# 8      Jerry Sloan         Spider
# 9  Charles Barkley  The Chuckster

# %%
df1.drop_duplicates(subset='Nickname', keep='last')
# Out:
#             Player       Nickname
# 0    Allen Iverson     The Answer
# 1   Earvin Johnson          Magic
# 4    John Williams        Hot Rod
# 5    George Gervin         Iceman
# 6   Michael Jordan     Air Jordan
# 8      Jerry Sloan         Spider
# 9  Charles Barkley  The Chuckster

# %%
df1.drop_duplicates(subset='Nickname', keep='first')
# Out:
#             Player       Nickname
# 0    Allen Iverson     The Answer
# 1   Earvin Johnson          Magic
# 2   Michael Jordan     Air Jordan
# 3   Rodney Hundley        Hot Rod
# 5    George Gervin         Iceman
# 7      John Salley         Spider
# 9  Charles Barkley  The Chuckster

# %%
# The original data remains intact. If you want to take effect to the original data-frame use inplace=True
df1
# Out:
#             Player       Nickname
# 0    Allen Iverson     The Answer
# 1   Earvin Johnson          Magic
# 2   Michael Jordan     Air Jordan
# 3   Rodney Hundley        Hot Rod
# 4    John Williams        Hot Rod
# 5    George Gervin         Iceman
# 6   Michael Jordan     Air Jordan
# 7      John Salley         Spider
# 8      Jerry Sloan         Spider
# 9  Charles Barkley  The Chuckster

# %% [markdown]
# **Replacing the Values Using Replace() or Fillna() Functions**

# %%
df1.replace('Michael Jordan', 'Mohd Sajjad Anver', inplace=True)

# %%
df1.replace('Air Jordan', 'sajjad', inplace=True)

# %% [markdown]
# To Replace Multiple Values Using replace()

# %%
df1.replace(['Hot Rod', 'Spider'], '** Duplicated **')
# Out:
#               Player          Nickname
# 0      Allen Iverson        The Answer
# 1     Earvin Johnson             Magic
# 2  Mohd Sajjad Anver            sajjad
# 3     Rodney Hundley  ** Duplicated **
# 4      John Williams  ** Duplicated **
# 5      George Gervin            Iceman
# 6  Mohd Sajjad Anver            sajjad
# 7        John Salley  ** Duplicated **
# 8        Jerry Sloan  ** Duplicated **
# 9    Charles Barkley     The Chuckster

# %% [markdown]
# **Replacing the values using the dictionary**

# %%
translation = {'Allen Iverson' : 'AI', 'Earvin Johnson': 'EJ', 'John Salley' : 'Johnny'}
df1.replace(translation)
# Out:
#               Player       Nickname
# 0                 AI     The Answer
# 1                 EJ          Magic
# 2  Mohd Sajjad Anver         sajjad
# 3     Rodney Hundley        Hot Rod
# 4      John Williams        Hot Rod
# 5      George Gervin         Iceman
# 6  Mohd Sajjad Anver         sajjad
# 7             Johnny         Spider
# 8        Jerry Sloan         Spider
# 9    Charles Barkley  The Chuckster

# %% [markdown]
# Map the Nickname Column Using a function. The function tries to find the key in the Translation dictionary

# %%
from types import LambdaType
translator = {'The Answer': 'Reply Maniac', 'Hot Rod': 'HRD', 'The Chuckster': 'The Chuck'}
df1['Nickname'] = df1['Nickname'].map(lambda key : translator.get(key, key))
df1
# Out:
#               Player      Nickname
# 0      Allen Iverson  Reply Maniac
# 1     Earvin Johnson         Magic
# 2  Mohd Sajjad Anver        sajjad
# 3     Rodney Hundley           HRD
# 4      John Williams           HRD
# 5      George Gervin        Iceman
# 6  Mohd Sajjad Anver        sajjad
# 7        John Salley        Spider
# 8        Jerry Sloan        Spider
# 9    Charles Barkley     The Chuck
